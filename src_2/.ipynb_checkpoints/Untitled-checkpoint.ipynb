# %%
import pandas as pd
import yaml

### User defined
import variables_n_functions as vnf

config_file = open('config.yaml', 'r')
config = yaml.safe_load(config_file)

teams = config['teams']

### We initialize the df with the appropriate column names
df = pd.DataFrame(columns = vnf.columnas_df)

### The following variable is auxiliar to avoid duplicate requests
teams_aux = list(teams.keys())

### We recover the match history between every unique team - team combination, and store it in the df
for team_1 in teams.keys():
    teams_aux.remove(team_1)
    for team_2 in teams_aux:
        h2h = vnf.head2head(team_1, team_2, config['sports_token'])
        df = pd.concat([df] + [pd.DataFrame(pd.Series(h2h[k])).transpose() for k in range(len(h2h))])    
# RENAME COLUMN due to reserved keyword
df.rename(columns = {'time':'time_data'}, inplace = True)

# %%
import mysql.connector

client = mysql.connector.connect(**config['connection'])
cursor = client.cursor()

#### Create DB and Tables

with open('sql/create_h2h_db.sql') as ddl:
    cursor.execute(ddl.read())

with open('sql/create_h2h_source.sql') as ddl:
    cursor.execute(ddl.read())

# %%
def list_of_tuples(df):
    
    all_values = []
    
    for k in range(df.shape[0]):
        temp = df.iloc[k]
        temp = temp.astype(str)
        temp = tuple(temp)
        all_values.append(temp)
        
    return all_values

source_values = list_of_tuples(df)


for value in source_values:
    with open('sql/insert_h2h_source.sql') as dml:
        try:
            cursor.execute(dml.read(), value)
            dml.close()
        except mysql.connector.IntegrityError as err:
            print("Something went wrong: {}".format(err))
            dml.close()
            pass

client.commit()

# %%
pd.read_sql('SELECT * FROM h2h.sports_monks', con=client)
# Out:
#            id league_id season_id  stage_id round_id group_id aggregate_id  \
# 0    18137071       501     18369  77453684   247462     None         None
# 1    18137008       501     18369  77453684   247452     None         None
# 2    18136904       501     18369  77453684   247434     None         None
# 3    17947857       501     17141  77447500   240676   243965         None
# 4    16475470       501     17141  77447501   194999     None         None
# ..        ...       ...       ...       ...      ...      ...          ...
# 137  11783968       501      1928      3209    51857     None         None
# 138    373750       501      1927      3206    51826   225153         None
# 139    373785       501      1927      3207    51843     None         None
# 140    373859       501      1927      3207    51837     None         None
# 141  11783885       501      1927      3207    51830     None         None
#
#     venue_id referee_id localteam_id  ...  \
# 0       8914      14859           62  ...
# 1       8909      14853           53  ...
# 2       8914      18748           62  ...
# 3       8914      14468           62  ...
# 4       8909      14859           53  ...
# ..       ...        ...          ...  ...
# 137     8946       None           66  ...
# 138     8946       None           66  ...
# 139     8914       None           62  ...
# 140     8946       None           66  ...
# 141     8914       None           62  ...
#
#                                             formations  \
# 0    {'localteam_formation': '4-2-3-1', 'visitortea...
# 1    {'localteam_formation': '4-3-3', 'visitorteam_...
# 2    {'localteam_formation': '4-3-3', 'visitorteam_...
# 3    {'localteam_formation': '4-3-1-2', 'visitortea...
# 4    {'localteam_formation': '4-2-3-1', 'visitortea...
# ..                                                 ...
# 137  {'localteam_formation': None, 'visitorteam_for...
# 138  {'localteam_formation': None, 'visitorteam_for...
# 139  {'localteam_formation': None, 'visitorteam_for...
# 140  {'localteam_formation': None, 'visitorteam_for...
# 141  {'localteam_formation': None, 'visitorteam_for...
#
#                                                 scores  \
# 0    {'localteam_score': 1, 'visitorteam_score': 2,...
# 1    {'localteam_score': 3, 'visitorteam_score': 0,...
# 2    {'localteam_score': 1, 'visitorteam_score': 0,...
# 3    {'localteam_score': 4, 'visitorteam_score': 1,...
# 4    {'localteam_score': 1, 'visitorteam_score': 1,...
# ..                                                 ...
# 137  {'localteam_score': 2, 'visitorteam_score': 1,...
# 138  {'localteam_score': 1, 'visitorteam_score': 2,...
# 139  {'localteam_score': 2, 'visitorteam_score': 0,...
# 140  {'localteam_score': 2, 'visitorteam_score': 1,...
# 141  {'localteam_score': 0, 'visitorteam_score': 3,...
#
#                                              time_data  \
# 0    {'status': 'FT', 'starting_at': {'date_time': ...
# 1    {'status': 'FT', 'starting_at': {'date_time': ...
# 2    {'status': 'FT', 'starting_at': {'date_time': ...
# 3    {'status': 'FT', 'starting_at': {'date_time': ...
# 4    {'status': 'FT', 'starting_at': {'date_time': ...
# ..                                                 ...
# 137  {'status': 'FT', 'starting_at': {'date_time': ...
# 138  {'status': 'FT', 'starting_at': {'date_time': ...
# 139  {'status': 'FT', 'starting_at': {'date_time': ...
# 140  {'status': 'FT', 'starting_at': {'date_time': ...
# 141  {'status': 'FT', 'starting_at': {'date_time': ...
#
#                                                coaches  \
# 0    {'localteam_coach_id': 23237, 'visitorteam_coa...
# 1    {'localteam_coach_id': 896805, 'visitorteam_co...
# 2    {'localteam_coach_id': 50, 'visitorteam_coach_...
# 3    {'localteam_coach_id': 50, 'visitorteam_coach_...
# 4    {'localteam_coach_id': 2163, 'visitorteam_coac...
# ..                                                 ...
# 137  {'localteam_coach_id': None, 'visitorteam_coac...
# 138  {'localteam_coach_id': None, 'visitorteam_coac...
# 139  {'localteam_coach_id': None, 'visitorteam_coac...
# 140  {'localteam_coach_id': None, 'visitorteam_coac...
# 141  {'localteam_coach_id': None, 'visitorteam_coac...
#
#                                              standings  \
# 0    {'localteam_position': 2, 'visitorteam_positio...
# 1    {'localteam_position': 2, 'visitorteam_positio...
# 2    {'localteam_position': 6, 'visitorteam_positio...
# 3    {'localteam_position': 1, 'visitorteam_positio...
# 4    {'localteam_position': 2, 'visitorteam_positio...
# ..                                                 ...
# 137  {'localteam_position': None, 'visitorteam_posi...
# 138  {'localteam_position': None, 'visitorteam_posi...
# 139  {'localteam_position': None, 'visitorteam_posi...
# 140  {'localteam_position': None, 'visitorteam_posi...
# 141  {'localteam_position': None, 'visitorteam_posi...
#
#                                             assistants  leg  \
# 0    {'first_assistant_id': 15817, 'second_assistan...  1/1
# 1    {'first_assistant_id': 12118, 'second_assistan...  1/1
# 2    {'first_assistant_id': 12118, 'second_assistan...  1/1
# 3    {'first_assistant_id': 12770, 'second_assistan...  1/1
# 4    {'first_assistant_id': 14860, 'second_assistan...  1/1
# ..                                                 ...  ...
# 137  {'first_assistant_id': None, 'second_assistant...  1/1
# 138  {'first_assistant_id': None, 'second_assistant...  1/1
# 139  {'first_assistant_id': None, 'second_assistant...  1/1
# 140  {'first_assistant_id': None, 'second_assistant...  1/1
# 141  {'first_assistant_id': None, 'second_assistant...  1/1
#
#                                                 colors deleted is_placeholder
# 0    {'localteam': {'color': '#2B72DE', 'kit_colors...   False          False
# 1    {'localteam': {'color': '#339063', 'kit_colors...   False          False
# 2    {'localteam': {'color': '#2B72DE', 'kit_colors...   False          False
# 3    {'localteam': {'color': '#2B72DE', 'kit_colors...   False          False
# 4    {'localteam': {'color': '#F0F0F0', 'kit_colors...   False          False
# ..                                                 ...     ...            ...
# 137                                               None   False          False
# 138                                               None   False          False
# 139                                               None   False          False
# 140                                               None   False          False
# 141                                               None   False          False
#
# [142 rows x 29 columns]

# %%
1
# Out:
# 1
